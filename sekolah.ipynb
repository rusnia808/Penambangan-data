# %%
from scipy import stats
import numpy as np
import seaborn as sns
import pandas as pd

df = pd.read_csv("sekolah.csv", sep=";")
df
# Out:
#      MATEMATIKA  BAHASA INDONESIA  BAHASA INGGRIS  IPA
# 0            83                97              91   78
# 1            89                99              58   71
# 2            72                95              62   73
# 3            99                73              87   75
# 4            64                88              81   90
# ..          ...               ...             ...  ...
# 494          96                74              67   68
# 495          99                82              97   70
# 496          61                81              63   80
# 497          63                86              92   67
# 498          64                73              72   77
#
# [499 rows x 4 columns]

# %%
import pandas as pd
from scipy import stats
df=pd.read_csv("sekolah.csv",sep=';')
data={"Stats":['Min','Max','Mean','Standard Deviasi','Variasi','Skewnes','Quantile 1','Quantile 2','Quantile 3','Median','Modus']}

for i in df.columns:
    data[i]=[df[i].min(),df[i].max(),df[i].mean(),
             round(df[i].std(), 2), round(df[i].var(), 2),
             round(df[i].skew(), 2), df[i].quantile(0.25),
             df[i].quantile(0.5), df[i].quantile(0.75),
             df[i].median(),stats.mode(df[i]).mode[0]]

tes = pd.DataFrame(data, columns = ['Stats']+[x for x in df.columns])
tes
# Out:
#                Stats  MATEMATIKA  BAHASA INDONESIA  BAHASA INGGRIS         IPA
# 0                Min   60.000000         65.000000       55.000000   60.000000
# 1                Max  100.000000        100.000000      100.000000  100.000000
# 2               Mean   80.308617         81.927856       77.859719   79.230461
# 3   Standard Deviasi   11.920000         10.340000       12.810000   11.730000
# 4            Variasi  142.110000        106.860000      164.030000  137.610000
# 5            Skewnes   -0.050000          0.100000        0.010000    0.050000
# 6         Quantile 1   71.000000         73.000000       67.000000   69.000000
# 7         Quantile 2   81.000000         81.000000       78.000000   79.000000
# 8         Quantile 3   90.000000         91.000000       88.000000   89.000000
# 9             Median   81.000000         81.000000       78.000000   79.000000
# 10             Modus   60.000000         78.000000       86.000000   61.000000

# %%
import matplotlib.pyplot as plt
plt.hist(df.values)
plt.show()
